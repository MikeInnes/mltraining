# %%
using Flux, Flux.Data.MNIST, Images
using Flux: onehotbatch, argmax, mse, throttle
using Base.Iterators: partition
using Images
using CuArrays

# %% [markdown]
# For this model we'll learn a compression scheme. The idea is to encode MNIST digits as small vectors that can then be decoded back into the original image.

# %%
imgs = MNIST.images()
vecs = float.(vec.(imgs))

# Partition into batches of size 1000
data = [gpu(hcat(vecs[i]...)) for i in partition(1:60_000, 1000)];
vecs = gpu.(vecs);

# %%
imgs[1:10]
# Out:
# 10-element Array{Array{ColorTypes.Gray{FixedPointNumbers.Normed{UInt8,8}},2},1}:
#  ColorTypes.Gray{FixedPointNumbers.Normed{UInt8,8}}[Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); … ; Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0)]
#  ColorTypes.Gray{FixedPointNumbers.Normed{UInt8,8}}[Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); … ; Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0)]
#  ColorTypes.Gray{FixedPointNumbers.Normed{UInt8,8}}[Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); … ; Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0)]
#  ColorTypes.Gray{FixedPointNumbers.Normed{UInt8,8}}[Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); … ; Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0)]
#  ColorTypes.Gray{FixedPointNumbers.Normed{UInt8,8}}[Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); … ; Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0)]
#  ColorTypes.Gray{FixedPointNumbers.Normed{UInt8,8}}[Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); … ; Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0)]
#  ColorTypes.Gray{FixedPointNumbers.Normed{UInt8,8}}[Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); … ; Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0)]
#  ColorTypes.Gray{FixedPointNumbers.Normed{UInt8,8}}[Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); … ; Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0)]
#  ColorTypes.Gray{FixedPointNumbers.Normed{UInt8,8}}[Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); … ; Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0)]
#  ColorTypes.Gray{FixedPointNumbers.Normed{UInt8,8}}[Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); … ; Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0); Gray{N0f8}(0.0) Gray{N0f8}(0.0) … Gray{N0f8}(0.0) Gray{N0f8}(0.0)]

# %%
N = 32 # Size of the encoding

encoder = Dense(28^2, N, relu)
decoder = Dense(N, 28^2, relu)

m = gpu(Chain(encoder, decoder))

loss(x) = mse(m(x), x)
# Out:
# loss (generic function with 1 method)

# %% [markdown]
# It's useful to be able to visualise what's happening in the network.

# %%
gray(x) = Gray(x)
img(x::AbstractVector) = collect(gray.(reshape(clamp.(x, 0, 1), 28, 28)))
# Out:
# img (generic function with 1 method)

# %% [markdown]
# First image:

# %%
imgs[1]
# Out:
# 28×28 Array{Gray{N0f8},2}:
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)

# %% [markdown]
# Round-trip through the model:

# %%
img(m(vecs[1]).data)
# Out:
# 28×28 Array{Gray{Float32},2}:
#  Gray{Float32}(0.0)        …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.010894)
#  Gray{Float32}(0.0793367)     Gray{Float32}(0.105437)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.093322)      Gray{Float32}(0.0154862)
#  Gray{Float32}(0.0)        …  Gray{Float32}(0.0713449)
#  Gray{Float32}(0.105837)      Gray{Float32}(0.0)
#  Gray{Float32}(0.0278455)     Gray{Float32}(0.0359756)
#  Gray{Float32}(0.162495)      Gray{Float32}(0.0298313)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.0)        …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  ⋮                         ⋱
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.113692)      Gray{Float32}(0.1459)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.0180061)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.177741)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.0)        …  Gray{Float32}(0.171118)
#  Gray{Float32}(0.0281577)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0618309)     Gray{Float32}(0.107403)

# %% [markdown]
# Random selection of 20 images:

# %%
function sample()
  # 20 random digits
  xs = [vecs[i] for i in rand(1:length(imgs), 20)]
  # Before and after images
  before, after = img.(xs), img.(map(x -> m(x).data, xs))
  # Stack them all together
  hcat(vcat.(before, after)...)
end
sample()
# Out:
# 56×560 Array{Gray{Float32},2}:
#  Gray{Float32}(0.0)        …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.0)        …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.0)        …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  ⋮                         ⋱
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.0)        …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0136846)     Gray{Float32}(0.0715171)
#  Gray{Float32}(0.0437153)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0394389)
#  Gray{Float32}(0.0)        …  Gray{Float32}(0.121766)
#  Gray{Float32}(0.103759)      Gray{Float32}(0.0)
#  Gray{Float32}(0.0)           Gray{Float32}(0.0)
#  Gray{Float32}(0.0567493)     Gray{Float32}(0.135222)
#  Gray{Float32}(0.0191726)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)        …  Gray{Float32}(0.0)

# %%
evalcb = function ()
    print_with_color(:blue, "Loss is $(loss(data[1][1]))")
    display(sample())
end
opt = ADAM(params(m))

for i = 1:10
    Flux.train!(loss, zip(data), opt)
    evalcb()
end
# Out:
# 56×560 Array{Gray{Float32},2}:
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  ⋮                                       ⋱
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
# Loss is 91.69822f0 (tracked)
# 56×560 Array{Gray{Float32},2}:
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  ⋮                                       ⋱
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
# Loss is 61.82618f0 (tracked)
# 56×560 Array{Gray{Float32},2}:
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  ⋮                                       ⋱
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
# Loss is 43.460476f0 (tracked)
# 56×560 Array{Gray{Float32},2}:
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  ⋮                                       ⋱
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
# Loss is 31.170729f0 (tracked)
# 56×560 Array{Gray{Float32},2}:
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  ⋮                                       ⋱
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
# Loss is 23.963322f0 (tracked)
# 56×560 Array{Gray{Float32},2}:
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  ⋮                                       ⋱
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
# Loss is 19.683807f0 (tracked)
# 56×560 Array{Gray{Float32},2}:
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  ⋮                                       ⋱
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
# Loss is 15.810961f0 (tracked)
# 56×560 Array{Gray{Float32},2}:
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  ⋮                                       ⋱
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
# Loss is 12.018653f0 (tracked)
# 56×560 Array{Gray{Float32},2}:
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  ⋮                                       ⋱
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
# Loss is 8.321562f0 (tracked)
# 56×560 Array{Gray{Float32},2}:
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  ⋮                                       ⋱
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
# Loss is 5.1196504f0 (tracked)
